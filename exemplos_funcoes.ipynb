# %%
#Função de Fatorial

# %%
def fat(n):
    if (n == 0):
        return 1
    return (n * fat(n-1))

# %%
print(fat(5))
# Out:
# 120

# %%
#Função Lambda de Fatorial

# %%
fat_lambda = lambda n: n * fat(n - 1) if n > 1 else 1

# %%
print(fat_lambda(5))
# Out:
# 120

# %%
#Função map com Lambda

# %%
lista = [1,2,3]
m = map(lambda x: x**2, lista)
for i in m:
    print(i)
# Out:
# 1
# 4
# 9

# %%
#Reduce
import functools

# %%
print(functools.reduce(lambda x,y: x+y, [1,2,3,4]))
# Out:
# 10

# %%
#Filter

# %%
f = filter(lambda x: x%2 == 0, range(10))
for i in f:
    print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
#Função Fibonacci

# %%
def fib(n):
    if(n == 1 or n == 2):
        return 1
    return fib(n-1) + fib(n-2)

print(fib(7))
# Out:
# 13

# %%
def pot(base, exp):
    if(exp == 0):
        return 1
    return base * pot(base, exp -1)

print(pot(10,2))
# Out:
# 100
